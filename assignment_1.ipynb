# %% [markdown]
# <a href="https://colab.research.google.com/github/Asmitx026/SEM-V_BWU_AI-Lab/blob/main/assignment_1_day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### PRACTICE: Inspect the capabilities of numpy, pandas and matplotlib

# %%
import numpy as np

matrix = np.array([[2,7,4],[2,7,1]])
print(f"Original Matrix: \n{matrix}")
# Out:
# Original Matrix:
# [[2 7 4]
#  [2 7 1]]

# %%
import pandas as pd

df = pd.DataFrame({
    'Models': ['GPT-5.6', 'Opus-4.8', 'Kimi-v2.6', 'Qwen-v4'],
    'Accuracy': [92.5,93.7,98.1,95.4]
})

display(df)

print("\nModels with high accuracy: ")
high_perf = df[df['Accuracy'] > 95]
display(high_perf)
# Out:
#       Models  Accuracy
# 0    GPT-5.6      92.5
# 1   Opus-4.8      93.7
# 2  Kimi-v2.6      98.1
# 3    Qwen-v4      95.4
# Models with high accuracy:
#       Models  Accuracy
# 2  Kimi-v2.6      98.1
# 3    Qwen-v4      95.4

# %%
from matplotlib import colors
import matplotlib.pyplot as plt

epochs = [1,2,3,4,5,6,7,8,9]
train_loss = [0.9,0.4,0.7,0.9,0.9,0.4,0.7,0.9,0.1]
val_loss = [0.95,0.91,0.94,0.98,0.96,0.95,0.91,0.98,0.99]

plt.figure(figsize=(8,6))
plt.plot(epochs, train_loss, label='Training Loss', color='royalblue', marker='o')
plt.plot(epochs, val_loss, label='Validation Loss', color='tomato', marker='*')

plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.title('Training and Validation Loss')
plt.legend()

plt.show()

# %% [markdown]
# ### Q1. Extract elements from an array using boolean masking

# %%
matrix = np.random.randint(1,16,(4,4))
print(matrix)
# Out:
# [[11  5  6  6]
#  [13  6  8 14]
#  [10 12 15 13]
#  [ 1  1  6  4]]

# %%
extracted = matrix[(matrix > 10) & (matrix % 2 == 0)]
print(extracted)
# Out:
# [14 12]

# %% [markdown]
# ### Q2. Plot 2 graphs in a single figure (`side by side`)
# - `Accuracy over Epochs` - Line Plot with Marker ('o')
# - `Inference Speed across Machines` - Bar Plot

# %%
np.random.seed(42)

epochs = np.linspace(1,5,5)
accuracy = np.random.uniform(90,99,(5))
accuracy.sort()

print(epochs)
print(accuracy)
# Out:
# [1. 2. 3. 4. 5.]
# [91.40416776 93.37086107 95.38792636 96.58794548 98.55642876]

# %%
inf_speed = pd.DataFrame({
    'machine': ['A','B','C'],
    'inf_speed': np.random.uniform(100,200,(3))
})

display(inf_speed)
# Out:
#   machine   inf_speed
# 0       A  115.599452
# 1       B  105.808361
# 2       C  186.617615

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(epochs, accuracy, marker='o', color='royalblue')

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy over Epochs Trend')

plt.subplot(1,2,2)
plt.bar(data=inf_speed, x='machine', height='inf_speed', color='royalblue')

plt.xlabel('Machine')
plt.ylabel('Inference Speed')
plt.title('Inference Speed across 3 Machines')

plt.show()
